# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
vgg_giraffe_cos_cluster_prec = np.loadtxt('results/vgg-giraffe-cos-cluster-prec.txt')
vgg_giraffe_cos_cluster_recall = np.loadtxt('results/vgg-giraffe-cos-cluster-recall.txt')
resnet_giraffe_cos_cluster_prec = np.loadtxt('results/resnet-giraffe-cos-cluster-prec.txt')
resnet_giraffe_cos_cluster_recall = np.loadtxt('results/resnet-giraffe-cos-cluster-recall.txt')
pca200_vgg_giraffe_cos_cluster_prec = np.loadtxt('results/pca200_vgg-giraffe-cos-cluster-prec.txt')
pca200_vgg_giraffe_cos_cluster_recall = np.loadtxt('results/pca200_vgg-giraffe-cos-cluster-recall.txt')
pca200_resnet_giraffe_cos_cluster_prec = np.loadtxt('results/pca200_resnet-giraffe-cos-cluster-prec.txt')
pca200_resnet_giraffe_cos_cluster_recall = np.loadtxt('results/pca200_resnet-giraffe-cos-cluster-recall.txt')
pca200_vgg_giraffe_smartcos_cluster_prec = np.loadtxt('results/pca200_vgg-giraffe-smartcos-cluster-prec.txt')
pca200_vgg_giraffe_smartcos_cluster_recall = np.loadtxt('results/pca200_vgg-giraffe-smartcos-cluster-recall.txt')

vgg_zebra_cos_cluster_prec = np.loadtxt('results/vgg-zebra-cos-cluster-prec.txt')
vgg_zebra_cos_cluster_recall = np.loadtxt('results/vgg-zebra-cos-cluster-recall.txt')
resnet_zebra_cos_cluster_prec = np.loadtxt('results/resnet-zebra-cos-cluster-prec.txt')
resnet_zebra_cos_cluster_recall = np.loadtxt('results/resnet-zebra-cos-cluster-recall.txt')
pca200_vgg_zebra_cos_cluster_prec = np.loadtxt('results/pca200_vgg-zebra-cos-cluster-prec.txt')
pca200_vgg_zebra_cos_cluster_recall = np.loadtxt('results/pca200_vgg-zebra-cos-cluster-recall.txt')
pca200_resnet_zebra_cos_cluster_prec = np.loadtxt('results/pca200_resnet-zebra-cos-cluster-prec.txt')
pca200_resnet_zebra_cos_cluster_recall = np.loadtxt('results/pca200_resnet-zebra-cos-cluster-recall.txt')
pca200_vgg_zebra_smartcos_cluster_prec = np.loadtxt('results/pca200_vgg-zebra-smartcos-cluster-prec.txt')
pca200_vgg_zebra_smartcos_cluster_recall = np.loadtxt('results/pca200_vgg-zebra-smartcos-cluster-recall.txt')

vgg_umbrella_cos_cluster_prec = np.loadtxt('results/vgg-umbrella-cos-cluster-prec.txt')
vgg_umbrella_cos_cluster_recall = np.loadtxt('results/vgg-umbrella-cos-cluster-recall.txt')
resnet_umbrella_cos_cluster_prec = np.loadtxt('results/resnet-umbrella-cos-cluster-prec.txt')
resnet_umbrella_cos_cluster_recall = np.loadtxt('results/resnet-umbrella-cos-cluster-recall.txt')
pca200_vgg_umbrella_cos_cluster_prec = np.loadtxt('results/pca200_vgg-umbrella-cos-cluster-prec.txt')
pca200_vgg_umbrella_cos_cluster_recall = np.loadtxt('results/pca200_vgg-umbrella-cos-cluster-recall.txt')
pca200_resnet_umbrella_cos_cluster_prec = np.loadtxt('results/pca200_resnet-umbrella-cos-cluster-prec.txt')
pca200_resnet_umbrella_cos_cluster_recall = np.loadtxt('results/pca200_resnet-umbrella-cos-cluster-recall.txt')
pca200_vgg_umbrella_smartcos_cluster_prec = np.loadtxt('results/pca200_vgg-umbrella-smartcos-cluster-prec.txt')
pca200_vgg_umbrella_smartcos_cluster_recall = np.loadtxt('results/pca200_vgg-umbrella-smartcos-cluster-recall.txt')

# %%
print(metrics.auc(vgg_giraffe_cos_cluster_recall, vgg_giraffe_cos_cluster_prec))
print(metrics.auc(resnet_giraffe_cos_cluster_recall, resnet_giraffe_cos_cluster_prec))
print(metrics.auc(pca200_vgg_giraffe_cos_cluster_recall, pca200_vgg_giraffe_cos_cluster_prec))
print(metrics.auc(pca200_resnet_giraffe_cos_cluster_recall, pca200_resnet_giraffe_cos_cluster_prec))
print(metrics.auc(pca200_vgg_giraffe_smartcos_cluster_recall, pca200_vgg_giraffe_smartcos_cluster_prec))
# Out:
# 0.21963399962790126
# 0.17551552436766343
# 0.1108186654260986
# 0.22558764850159685
# 0.6379669834048133

# %%
print(metrics.auc(vgg_zebra_cos_cluster_recall, vgg_zebra_cos_cluster_prec))
print(metrics.auc(resnet_zebra_cos_cluster_recall, resnet_zebra_cos_cluster_prec))
print(metrics.auc(pca200_vgg_zebra_cos_cluster_recall, pca200_vgg_zebra_cos_cluster_prec))
print(metrics.auc(pca200_resnet_zebra_cos_cluster_recall, pca200_resnet_zebra_cos_cluster_prec))
print(metrics.auc(pca200_vgg_zebra_smartcos_cluster_recall, pca200_vgg_zebra_smartcos_cluster_prec))
# Out:
# 0.6690144494938758
# 0.3793345481384404
# 0.6528843336965684
# 0.38477628742764935
# 0.7049489772724291

# %%
print(metrics.auc(vgg_umbrella_cos_cluster_recall, vgg_umbrella_cos_cluster_prec))
print(metrics.auc(resnet_umbrella_cos_cluster_recall, resnet_umbrella_cos_cluster_prec))
print(metrics.auc(pca200_vgg_umbrella_cos_cluster_recall, pca200_vgg_umbrella_cos_cluster_prec))
print(metrics.auc(pca200_resnet_umbrella_cos_cluster_recall, pca200_resnet_umbrella_cos_cluster_prec))
print(metrics.auc(pca200_vgg_umbrella_smartcos_cluster_recall, pca200_vgg_umbrella_smartcos_cluster_prec))
# Out:
# 0.3124000893134728
# 0.5242117579093191
# 0.48452591002273826
# 0.4352128323438509
# 0.7114680301065769

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(15,10))

ax1.plot([x for x in range(5000)], vgg_zebra_cos_cluster_prec[:5000], label='Similarity search (VGG)', linewidth=1)
ax1.plot([x for x in range(5000)], resnet_zebra_cos_cluster_prec[:5000], label='Similarity search (ResNet)', linewidth=1)
ax1.plot([x for x in range(5000)], pca200_vgg_zebra_cos_cluster_prec[:5000], label='Similarity search (VGG w PCA)', linewidth=1)
ax1.plot([x for x in range(5000)], pca200_resnet_zebra_cos_cluster_prec[:5000], label='Similarity search (ResNet w PCA)', linewidth=1)
ax1.plot([x for x in range(5000)], pca200_vgg_zebra_smartcos_cluster_prec[:5000], label='Active search (VGG w PCA)', linewidth=1)
ax1.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search baseline', linewidth=1)
# ax1.legend(loc='lower left')
ax1.set(xlabel='Number of frames selected', ylabel='Precision')
ax1.set_title("Precision on class 'zebra'")

ax2.plot([x for x in range(5000)], vgg_giraffe_cos_cluster_prec[:5000], label='SS VGG', linewidth=1)
ax2.plot([x for x in range(5000)], resnet_giraffe_cos_cluster_prec[:5000], label='SS ResNet', linewidth=1)
ax2.plot([x for x in range(5000)], pca200_vgg_giraffe_cos_cluster_prec[:5000], label='SS VGG w PCA', linewidth=1)
ax2.plot([x for x in range(5000)], pca200_resnet_giraffe_cos_cluster_prec[:5000], label='SS ResNet w PCA', linewidth=1)
ax2.plot([x for x in range(5000)], pca200_vgg_giraffe_smartcos_cluster_prec[:5000], label='Active search', linewidth=1)
ax2.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax2.legend(loc='lower left')
ax2.set(xlabel='Number of frames selected')
ax2.set_title("Precision on class 'giraffe'")

ax3.plot([x for x in range(5000)], vgg_umbrella_cos_cluster_prec[:5000], label='SS VGG', linewidth=1)
ax3.plot([x for x in range(5000)], resnet_umbrella_cos_cluster_prec[:5000], label='SS ResNet', linewidth=1)
ax3.plot([x for x in range(5000)], pca200_vgg_umbrella_cos_cluster_prec[:5000], label='SS VGG w PCA', linewidth=1)
ax3.plot([x for x in range(5000)], pca200_resnet_umbrella_cos_cluster_prec[:5000], label='SS ResNet w PCA', linewidth=1)
ax3.plot([x for x in range(5000)], pca200_vgg_umbrella_smartcos_cluster_prec[:5000], label='Active search', linewidth=1)
ax3.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax3.legend(loc='lower left')
ax3.set(xlabel='Number of frames selected')
ax3.set_title("Precision on class 'umbrella'")

ax4.plot([x for x in range(5000)], vgg_zebra_cos_cluster_recall[:5000], label='SS VGG', linewidth=1)
ax4.plot([x for x in range(5000)], resnet_zebra_cos_cluster_recall[:5000], label='SS ResNet', linewidth=1)
ax4.plot([x for x in range(5000)], pca200_vgg_zebra_cos_cluster_recall[:5000], label='SS VGG w PCA', linewidth=1)
ax4.plot([x for x in range(5000)], pca200_resnet_zebra_cos_cluster_recall[:5000], label='SS ResNet w PCA', linewidth=1)
ax4.plot([x for x in range(5000)], pca200_vgg_zebra_smartcos_cluster_recall[:5000], label='Active search', linewidth=1)
ax4.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax4.legend(loc='upper left')
ax4.set(xlabel='Number of frames selected', ylabel='Recall')
ax4.set_title("Recall on class 'zebra'")

ax5.plot([x for x in range(5000)], vgg_giraffe_cos_cluster_recall[:5000], label='SS VGG', linewidth=1)
ax5.plot([x for x in range(5000)], resnet_giraffe_cos_cluster_recall[:5000], label='SS ResNet', linewidth=1)
ax5.plot([x for x in range(5000)], pca200_vgg_giraffe_cos_cluster_recall[:5000], label='SS VGG w PCA', linewidth=1)
ax5.plot([x for x in range(5000)], pca200_resnet_giraffe_cos_cluster_recall[:5000], label='SS ResNet w PCA', linewidth=1)
ax5.plot([x for x in range(5000)], pca200_vgg_giraffe_smartcos_cluster_recall[:5000], label='Active search', linewidth=1)
ax5.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax5.legend(loc='upper left')
ax5.set(xlabel='Number of frames selected')
ax5.set_title("Recall on class 'giraffe'")

ax6.plot([x for x in range(5000)], vgg_umbrella_cos_cluster_recall[:5000], label='SS VGG-16', linewidth=1)
ax6.plot([x for x in range(5000)], resnet_umbrella_cos_cluster_recall[:5000], label='SS ResNet-50', linewidth=1)
ax6.plot([x for x in range(5000)], pca200_vgg_umbrella_cos_cluster_recall[:5000], label='SS VGG-16 w PCA', linewidth=1)
ax6.plot([x for x in range(5000)], pca200_resnet_umbrella_cos_cluster_recall[:5000], label='SS ResNet-50 w PCA', linewidth=1)
ax6.plot([x for x in range(5000)], pca200_vgg_umbrella_smartcos_cluster_recall[:5000], label='Active search', linewidth=1)
ax6.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax6.legend(loc='upper left')
ax6.set(xlabel='Number of frames selected')
ax6.set_title("Recall on class 'umbrella'")

ax7.plot(vgg_zebra_cos_cluster_recall, vgg_zebra_cos_cluster_prec, label='SS VGG', linewidth=1)
ax7.plot(resnet_zebra_cos_cluster_recall, resnet_zebra_cos_cluster_prec, label='SS ResNet', linewidth=1)
ax7.plot(pca200_vgg_zebra_cos_cluster_recall, pca200_vgg_zebra_cos_cluster_prec, label='SS VGG w PCA', linewidth=1)
ax7.plot(pca200_resnet_zebra_cos_cluster_recall, pca200_resnet_zebra_cos_cluster_prec, label='SS ResNet w PCA', linewidth=1)
ax7.plot(pca200_vgg_zebra_smartcos_cluster_recall, pca200_vgg_zebra_smartcos_cluster_prec, label='Active search', linewidth=1)
ax7.plot([x/10 for x in range(11)], [515/200000 for x in range(11)], '--', label='Random search', linewidth=1)
# ax7.legend(loc='upper right')
ax7.set(xlabel='Recall', ylabel='Precision')
ax7.set_title("Precision-recall curve for class 'zebra'")

ax8.plot(vgg_giraffe_cos_cluster_recall, vgg_giraffe_cos_cluster_prec, label='SS VGG', linewidth=1)
ax8.plot(resnet_giraffe_cos_cluster_recall, resnet_giraffe_cos_cluster_prec, label='SS ResNet', linewidth=1)
ax8.plot(pca200_vgg_giraffe_cos_cluster_recall, pca200_vgg_giraffe_cos_cluster_prec, label='SS VGG w PCA', linewidth=1)
ax8.plot(pca200_resnet_giraffe_cos_cluster_recall, pca200_resnet_giraffe_cos_cluster_prec, label='SS ResNet w PCA', linewidth=1)
ax8.plot(pca200_vgg_giraffe_smartcos_cluster_recall, pca200_vgg_giraffe_smartcos_cluster_prec, label='Active search', linewidth=1)
ax8.plot([x/10 for x in range(11)], [968/200000 for x in range(11)], '--', label='Random search', linewidth=1)
# ax8.legend(loc='upper right')
ax8.set(xlabel='Recall', ylabel='Precision')
ax8.set_title("Precision-recall curve for class 'giraffe'")

ax9.plot(vgg_umbrella_cos_cluster_recall, vgg_umbrella_cos_cluster_prec, label='SS VGG', linewidth=1)
ax9.plot(resnet_umbrella_cos_cluster_recall, resnet_umbrella_cos_cluster_prec, label='SS ResNet', linewidth=1)
ax9.plot(pca200_vgg_umbrella_cos_cluster_recall, pca200_vgg_umbrella_cos_cluster_prec, label='SS VGG w PCA', linewidth=1)
ax9.plot(pca200_resnet_umbrella_cos_cluster_recall, pca200_resnet_umbrella_cos_cluster_prec, label='SS ResNet w PCA', linewidth=1)
ax9.plot(pca200_vgg_umbrella_smartcos_cluster_recall, pca200_vgg_umbrella_smartcos_cluster_prec, label='Active search', linewidth=1)
ax9.plot([x/10 for x in range(11)], [3886/200000 for x in range(11)], '--', label='Random search', linewidth=1)
# ax9.legend(loc='upper right')
ax9.set(xlabel='Recall', ylabel='Precision')
ax9.set_title("Precision-recall curve for class 'umbrella'")

handles, labels = ax1.get_legend_handles_labels()
lgd = fig.legend(handles, labels, bbox_to_anchor=(1.05, 1.03), ncol=6)

fig.tight_layout()
fig.show()
fig.savefig('plots.png', bbox_extra_artists=(lgd,), bbox_inches='tight', facecolor='w')

# %%
print(vgg_zebra_cos_cluster_recall[1000])
print(resnet_zebra_cos_cluster_recall[1000])
print(pca200_vgg_zebra_cos_cluster_recall[1000])
print(pca200_resnet_zebra_cos_cluster_recall[1000])
print(pca200_vgg_zebra_smartcos_cluster_recall[1000])
# Out:
# 0.8176470588235294
# 0.596078431372549
# 0.7980392156862746
# 0.5705882352941176
# 0.9372549019607843

# %%
print(vgg_giraffe_cos_cluster_recall[1000])
print(resnet_giraffe_cos_cluster_recall[1000])
print(pca200_vgg_giraffe_cos_cluster_recall[1000])
print(pca200_resnet_giraffe_cos_cluster_recall[1000])
print(pca200_vgg_giraffe_smartcos_cluster_recall[1000])
# Out:
# 0.2533748701973001
# 0.1838006230529595
# 0.12876427829698858
# 0.23572170301142265
# 0.6770508826583593

# %%
print(vgg_umbrella_cos_cluster_recall[1000])
print(resnet_umbrella_cos_cluster_recall[1000])
print(pca200_vgg_umbrella_cos_cluster_recall[1000])
print(pca200_resnet_umbrella_cos_cluster_recall[1000])
print(pca200_vgg_umbrella_smartcos_cluster_recall[1000])
# Out:
# 0.17418191187838186
# 0.21618139654728163
# 0.21257407884565835
# 0.19917547023962895
# 0.23473331615562998

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(11,6))

ax1.plot([x for x in range(5000)], vgg_zebra_cos_cluster_recall[:5000], label='Standard search (VGG)', linewidth=1)
ax1.plot([x for x in range(5000)], resnet_zebra_cos_cluster_recall[:5000], label='Standard search (ResNet)', linewidth=1)
ax1.plot([x for x in range(5000)], pca200_vgg_zebra_cos_cluster_recall[:5000], label='Standard search (VGG w PCA)', linewidth=1)
ax1.plot([x for x in range(5000)], pca200_resnet_zebra_cos_cluster_recall[:5000], label='Standard search (ResNet w PCA)', linewidth=1)
ax1.plot([x for x in range(5000)], pca200_vgg_zebra_smartcos_cluster_recall[:5000], label='Active search (VGG w PCA)', linewidth=1)
ax1.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax4.legend(loc='upper left')
ax1.set(xlabel='Number of frames selected', ylabel='Recall')
ax1.set_title("Recall on zebra")

ax2.plot([x for x in range(5000)], vgg_giraffe_cos_cluster_recall[:5000], label='SS VGG', linewidth=1)
ax2.plot([x for x in range(5000)], resnet_giraffe_cos_cluster_recall[:5000], label='SS ResNet', linewidth=1)
ax2.plot([x for x in range(5000)], pca200_vgg_giraffe_cos_cluster_recall[:5000], label='SS VGG w PCA', linewidth=1)
ax2.plot([x for x in range(5000)], pca200_resnet_giraffe_cos_cluster_recall[:5000], label='SS ResNet w PCA', linewidth=1)
ax2.plot([x for x in range(5000)], pca200_vgg_giraffe_smartcos_cluster_recall[:5000], label='Active search', linewidth=1)
ax2.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax5.legend(loc='upper left')
ax2.set(xlabel='Number of frames selected')
ax2.set_title("Recall on giraffe")

ax3.plot([x for x in range(5000)], vgg_umbrella_cos_cluster_recall[:5000], label='SS VGG-16', linewidth=1)
ax3.plot([x for x in range(5000)], resnet_umbrella_cos_cluster_recall[:5000], label='SS ResNet-50', linewidth=1)
ax3.plot([x for x in range(5000)], pca200_vgg_umbrella_cos_cluster_recall[:5000], label='SS VGG-16 w PCA', linewidth=1)
ax3.plot([x for x in range(5000)], pca200_resnet_umbrella_cos_cluster_recall[:5000], label='SS ResNet-50 w PCA', linewidth=1)
ax3.plot([x for x in range(5000)], pca200_vgg_umbrella_smartcos_cluster_recall[:5000], label='Active search', linewidth=1)
ax3.plot([x for x in range(5000)], [1/200000 for x in range(5000)], '--', label='Random search', linewidth=1)
# ax6.legend(loc='upper left')
ax3.set(xlabel='Number of frames selected')
ax3.set_title("Recall on umbrella")

ax4.plot(vgg_zebra_cos_cluster_recall, vgg_zebra_cos_cluster_prec, label='SS VGG', linewidth=1)
ax4.plot(resnet_zebra_cos_cluster_recall, resnet_zebra_cos_cluster_prec, label='SS ResNet', linewidth=1)
ax4.plot(pca200_vgg_zebra_cos_cluster_recall, pca200_vgg_zebra_cos_cluster_prec, label='SS VGG w PCA', linewidth=1)
ax4.plot(pca200_resnet_zebra_cos_cluster_recall, pca200_resnet_zebra_cos_cluster_prec, label='SS ResNet w PCA', linewidth=1)
ax4.plot(pca200_vgg_zebra_smartcos_cluster_recall, pca200_vgg_zebra_smartcos_cluster_prec, label='Active search', linewidth=1)
ax4.plot([x/10 for x in range(11)], [515/200000 for x in range(11)], '--', label='Random search', linewidth=1)
# ax7.legend(loc='upper right')
ax4.set(xlabel='Recall', ylabel='Precision')
ax4.set_title("Precision-recall curve for zebra")

ax5.plot(vgg_giraffe_cos_cluster_recall, vgg_giraffe_cos_cluster_prec, label='SS VGG', linewidth=1)
ax5.plot(resnet_giraffe_cos_cluster_recall, resnet_giraffe_cos_cluster_prec, label='SS ResNet', linewidth=1)
ax5.plot(pca200_vgg_giraffe_cos_cluster_recall, pca200_vgg_giraffe_cos_cluster_prec, label='SS VGG w PCA', linewidth=1)
ax5.plot(pca200_resnet_giraffe_cos_cluster_recall, pca200_resnet_giraffe_cos_cluster_prec, label='SS ResNet w PCA', linewidth=1)
ax5.plot(pca200_vgg_giraffe_smartcos_cluster_recall, pca200_vgg_giraffe_smartcos_cluster_prec, label='Active search', linewidth=1)
ax5.plot([x/10 for x in range(11)], [968/200000 for x in range(11)], '--', label='Random search', linewidth=1)
# ax8.legend(loc='upper right')
ax5.set(xlabel='Recall', ylabel='Precision')
ax5.set_title("Precision-recall curve for giraffe")

ax6.plot(vgg_umbrella_cos_cluster_recall, vgg_umbrella_cos_cluster_prec, label='SS VGG', linewidth=1)
ax6.plot(resnet_umbrella_cos_cluster_recall, resnet_umbrella_cos_cluster_prec, label='SS ResNet', linewidth=1)
ax6.plot(pca200_vgg_umbrella_cos_cluster_recall, pca200_vgg_umbrella_cos_cluster_prec, label='SS VGG w PCA', linewidth=1)
ax6.plot(pca200_resnet_umbrella_cos_cluster_recall, pca200_resnet_umbrella_cos_cluster_prec, label='SS ResNet w PCA', linewidth=1)
ax6.plot(pca200_vgg_umbrella_smartcos_cluster_recall, pca200_vgg_umbrella_smartcos_cluster_prec, label='Active search', linewidth=1)
ax6.plot([x/10 for x in range(11)], [3886/200000 for x in range(11)], '--', label='Random search', linewidth=1)
# ax9.legend(loc='upper right')
ax6.set(xlabel='Recall', ylabel='Precision')
ax6.set_title("Precision-recall curve for umbrella")

handles, labels = ax1.get_legend_handles_labels()
lgd = fig.legend(handles, labels, bbox_to_anchor=(1.00, 1.08), ncol=3)

fig.tight_layout()
fig.show()
fig.savefig('plots2.png', bbox_extra_artists=(lgd,), bbox_inches='tight', facecolor='w')
